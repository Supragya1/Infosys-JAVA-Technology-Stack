# %% [markdown]
# **Q1 of 4**
#
# What will be the output of the code given below?
#
# ```java
# public class Computer {
# 	private int id;
# }
#
# public class Student {
# 	public void assessment(Computer c) {
# 		System.out.println("Student appeared for exam using PC Id: " + c.id);
# 	}
#
# 	public static void main(String args[]) {
# 		Student s = new Student();
# 		Computer c = new Computer();
# 		s.assessment(c);
# 	}
# }
# ```
#
# - Student appeared for exam using PC Id: 0 []
# - Student appeared for exam using PC Id: garbage value []
# - compilation error: no constructor is present in Computer class []
# - compilation error: id is private and cannot be accessed directly in another class [x]
#
# Explanation :
#
# id is a private variable and is not accessible outside the class.
#
# **Q2 of 4**
#
# Observe the below classes. Replace //missing code so that findSum() calculates the variable sum as the sum of all the objects of array b.
#
# ```java
# public class B {
# 	public int num;
#
# 	public B(int b) {
# 		num = b;
# 	}
# }
#
# public class A {
# 	public int num;
#
# 	public void findSum(B[] b) {
# 		int sum = 0;
# 		for (B item : b) {
# 			// missing code
# 		}
# 	}
# }
# ```
# - sum+=num []
# - sum += item.num [x]
# - sum += B.num []
# - sum += item.getNum() []
#
# Explanation :
# The instance variable num of class B need to be accessed here and it is accessed using item.
#
# **Q3 of 4**
# What will be the output of the below code?
#
# ```java
# class Cabin {
# 	public int cabinNumber;
#
# 	Cabin(int number) {
# 		this.cabinNumber = number;
# 	}
# }
#
# public class Professor {
# 	public String name;
# 	public Cabin cabin;
#
# 	public Professor(String name, Cabin c) {
# 		this.name = name;
# 		this.cabin = c;
# 	}
#
# 	public void updateCabin(Cabin c) {
# 		this.cabin.cabinNumber = c.cabinNumber;
# 	}
#
# 	public static void main(String args[]) {
# 		Cabin c1 = new Cabin(121);
# 		Professor p1 = new Professor("Ronald", c1);
# 		Professor p2 = new Professor("Bonnie", c1);
# 		Cabin c2 = new Cabin(122);
# 		p1.updateCabin(c2);
# 		System.out.println(p1.cabin.cabinNumber);
# 		System.out.println(p2.cabin.cabinNumber);
# 	}
# }
# ```
#
# - 122 122 [x]
# - 122 121 []
# - Compilation error: cannot directly access cabinNumber of class Cabin inside class Professor []
# - Compilation error: cannot assign c1 to p2 since it has already been assigned to p1 []
#
#
# Explanation :
# In updateCabin(), the cabinNumber of c1 gets updated.
#
# **Q4 of 4**
#
# Which of the below relations can be bidirectional?
#
# If class A is related to class B by _______ then class B can also be related to class A by __________.
#
# - Aggregation []
# - Association [x]
# - Both []
# - None []
#
# Explanation :
#
# If class A uses class B, then, class B may or may not use class A.
