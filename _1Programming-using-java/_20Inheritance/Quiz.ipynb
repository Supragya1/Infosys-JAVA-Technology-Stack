# %% [markdown]
# **Q1 of 4**
#
# Predict the output of the following code:
# ``` java
# class Customer {
# 	public Customer() {
# 		System.out.println("Customer");
# 	}
# }
#
# class RegularCustomer extends Customer {
# 	public RegularCustomer() {
# 		System.out.println("Regular Customer");
# 	}
# }
#
# class PremiumCustomer extends RegularCustomer {
# 	public PremiumCustomer() {
# 		System.out.println("Premium Customer");
# 	}
# }
#
# public class Tester {
# 	public static void main(String[] args) {
# 		PremiumCustomer premiumCusotmer = new PremiumCustomer();
# 	}
# }
# ```
#
# - Customer Regular Customer Premium Customer [x]
# - Premium Customer []
# - Regular Customer []
# - Customer []
#
# Explanation :
# When a child class object is created, the child class constructor implicitly invokes the parameterless constructor of the parent class.
#
# **Q2 of 4**
#
# In the constructor of DigitalCamera class, the call to the base class constructor  ____________.
#
# ``` java
# class Camera {
# 	private String brand;
# 	private int cost;
#
# 	Camera() {
# 		this.brand = "Nikon";
# 	}
#
# 	Camera(String brand, int cost) {
# 		this.brand = brand;
# 		this.cost = cost;
# 	}
# }
#
# public class DigitalCamera extends Camera {
# 	private int memory;
#
# 	DigitalCamera(String brand, int cost) {
# 		this.memory = 16;
# 	}
#
# 	public static void main(String[] args) {
# 		DigitalCamera Camera = new DigitalCamera("Canon", 100);
# 	}
# }
# ```
#
# - can be made anywhere in the constructor
# - must be made in the first line of the constructor [x]
#
# Explanation :
# A base class constructor can be called only in the first line of a constructor.
#
# **Q3 of 4**
# Predict the output of the following code.
# ``` java
# class A {
# 	private int var1 = 10;
# 	private int var2;
#
# 	A(int var2) {
# 		this.var2 = var2;
# 	}
#
# 	public int getVar1() {
# 		return var1;
# 	}
#
# 	public void setVar1(int var1) {
# 		this.var1 = var1;
# 	}
#
# 	public int getVar2() {
# 		return var2;
# 	}
#
# 	public void setVar2(int var2) {
# 		this.var2 = var2;
# 	}
# }
#
# class B extends A {
# 	private int var3;
#
# 	B(int var2, int var3) {
# 		super(var2);
# 		this.var3 = 40; // line 33
# 	}
#
# 	public int add() {
# 		int sum;
# 		sum = getVar1() + getVar2() + var3;
# 		System.out.println("Result: " + sum);
# 		return sum;
# 	}
# }
#
# public class Tester {
# 	public static void main(String[] args) {
# 		B obj = new B(20, 30);
# 		obj.add();
# 	}
# }
# ```
# - Result: 60 []
# - Result: 70 [x]
# - Error at line33: ambiguity in assigning values []
# - Result: 50 []
#
# Explanation :
# var1 is initialized to 10, var2 to 20 and var3 to 40.
# Hence, the sum is 10 + 20 + 40 = 70.
#
# **Q4 of 4**
# Which of the following statements are true about constructors in Java?
#
# - If constructor for a class is not defined, then the compiler automatically provides a default parameterless constructor [x]
# - The name of the constructor should be same as the class name [x]
# - The parameterless constructor of the parent class is invoked implicitly by the child class constructors if super() is not explicitly used in the child class constructor [x]
# - A call to a parent class constructor must be the first statement inside the child class constructor [x]
#
# Explanation :
# A default parameterless constructor is supplied by Java if no user-defined constructor is created in a class.
#
# Explanation :
# The constructor name should be the same as the class name.
#
# Explanation :
# The parameterless constructor of a parent class is implicitly invoked by a child class constructor if a constructor of the parent class is not explicitly invoked in the child class constructor.
#
# Explanation :
# A call to a parent class constructor must be the first statement inside the child class constructor.
