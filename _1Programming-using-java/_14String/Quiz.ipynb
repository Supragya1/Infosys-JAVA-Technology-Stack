# %% [markdown]
# **Q1 of 6**
#
# What will be the output of the below code?
#
# ``` java
# public class Tester {
# 	public static void main(String args[]) {
# 		String str = "How Are You?";
# 		System.out.println(str.charAt(str.length()));
# 	}
#
# }
#  ```
#
# - ? []
# - u []
# - compilation error: string cannot store special characters []
# - runtime error: index out of bounds [x]
#
# Explanation :
#
# String index starts from 0. The index of the last character('?') is 11 but the length of the string is 12. So, there will be a runtime error as the size of the string will be exceeded.
#
# **Q2 of 6**
#
# What will be the output of the below code?
#
# ``` java
# public class Tester {
# 	public static void main(String args[]) {
# 		String num = "10";
# 		int n = 20;
# 		System.out.println(num + n);
# 	}
#
# }
# ```
#
# - 30 []
# - 1020 [x]
# - compilation error: cannot convert int to string []
# - 10 []
#
# Explanation :
#
# When you use '+' operator with a string, it behaves as a concatenation operator. So, here 10 and 20 are concatenated and the output is 1020
#
# **Q3 of 6**
# Q3 of 6
#
# What will be the output of the below code?
#
# ``` java
# public class Tester {
# 	public static void main(String args[]) {
# 		String s1 = "abc";
# 		String s2 = "abcd";
# 		System.out.println(s1 = s2);
# 	}
# }
# ```
#
# - abc []
# - abcd [x]
# - true []
# - compilation error: cannot convert from string to boolean []
#
# Explanation :
#
# = operator assigns the value of s2 to s1 and hence, 'abcd' is displayed.
#
# **Q4 of 6**
#
# What will be the output of the below code?
#
# ``` java
# public class Tester {
# 	public static void main(String args[]) {
# 		String s1 = "abc";
# 		String s2 = new String("abc");
# 		System.out.println(s1.equals(s2));
# 		System.out.println(s1 == s2);
# 	}
# }
# ```
# - true false [x]
# - false true []
# - true true []
# - false false []
#
# Explanation :
#
# equals method compares only the values and == operator compares the object references. Hence, the output is true false.
#
# **Q5 of 6**
#
# What will be the output of the below code?
#
# ``` java
# public class Tester {
# 	public static void main(String[] args) {
# 		String passengerFirstName = "James";
# 		String p1 = passengerFirstName.toUpperCase();
# 		System.out.println(p1.equals(passengerFirstName));
# 		System.out.println(p1.equalsIgnoreCase(passengerFirstName));
# 	}
# }
# ```
#
# - true true []
# - true false []
# - false true [x]
# - false false []
#
# Explanation :
#
# equals() method considers case during comparison and equalsIgnoreCase() method ignores case during comparison. Hence, the output is false true.
#
# **Q6 of 6**
#
# What will be the output of the below code?
#
# ``` java
# public class Tester {
# 	public static void main(String args[]) {
# 		String input = "welcome to string functions";
# 		input.toUpperCase();
# 		System.out.println(input);
# 	}
#
# }
# ```
#
# - null []
# - WELCOME TO STRING FUNCTIONS []
# - welcome to string functions [x]
# - compilation error: method toUpperCase is undefined for string []
#
# Explanation :
#
# String input is converted to upper case but the output of toUpperCase() is not being stored in any string.
