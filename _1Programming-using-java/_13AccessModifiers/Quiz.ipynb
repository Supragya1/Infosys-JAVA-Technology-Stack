# %% [markdown]
# **Q1 of 4**
#
# What is the output of the below code?
#
# ```java
# class A {
# 	private void displayMessage() {
# 		System.out.println("Welcome");
# 	}
# }
#
# public class B {
# 	public static void main(String args[]) {
# 		A message = new A();
# 		message.displayMessage();
# 	}
# }
# ```
#
# - Welcome []
# - null []
# - No output []
# - Compilation error: The method displayMessage() from type A is not visible [x]
#
# Explanation :
#
# displayMessage() is a private method and hence, there will be a compilation error.
#
# **Q2 of 4**
#
# What is the output of the below code?
#
# ```java
# class A {
# 	public void displayMessage() {
# 		System.out.println("Welcome");
# 	}
# }
#
# public class B {
# 	public static void main(String args[]) {
# 		A message = new A();
# 		message.displayMessage();
# 	}
# }
# ```
#
# - Welcome [x]
# - null []
# - No output []
# - Compilation error: The method displayMessage() from type A is not visible []
#
# Explanation :
#
# Welcome is being displayed in the method displayMessage().
#
# **Q3 of 4**
#
# Which of the following statements are correct?
#
# i. public methods of a class can be accessed anywhere in a program
#
# ii. private methods of a class can be accessed only inside the class
#
# iii. members created without any access modifier will have default access
#
# - Only i and ii []
# - All i, ii and iii [x]
# - Only i and iii []
# - Only ii and iii []
# Explanation :
#
# All the statements are true
#
# **Q4 of 4**
#
# What is the output of the below code?
#
# ```java
# class Purchase {
# 	private String mobileName;
# 	private int price;
# 	private int stock;
#
# 	public void purchaseMobile() {
# 		stock = stock - 1;
# 	}
#
# 	public String getMobileName() {
# 		return mobileName;
# 	}
#
# 	public void setMobileName(String mobileName) {
# 		this.mobileName = mobileName;
# 	}
#
# 	public int getPrice() {
# 		return price;
# 	}
#
# 	public void setPrice(int price) {
# 		this.price = price;
# 	}
#
# 	public int getStock() {
# 		return stock;
# 	}
#
# 	public void setStock(int stock) {
# 		this.stock = stock;
# 	}
#
# }
#
# public class Tester {
# 	public static void main(String[] args) {
# 		Purchase mobile = new Purchase();
# 		mobile.setMobileName("Moto");
# 		mobile.setPrice(200);
# 		mobile.purchaseMobile();
# 		System.out.println(mobile.getStock());
# 	}
# }
# ```
#
# - Compilation error: stock is not initialized []
# - null []
# - 0 []
# - -1 [x]
#
# Explanation :
#
# stock is initialized to 0(default value) since it is not initialized explicitly and the value of stock is being decremented in purchaseMobile method. So, stock gets updated to -1.
