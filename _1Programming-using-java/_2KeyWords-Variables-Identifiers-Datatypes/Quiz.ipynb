# %% [markdown]
# **Q1 of 5**
#
# Which of the following are valid identifiers?
#
# - abc [x]
# - Student [x]
# - class []
# - public []
# - 1num []
# - result [x]
#
# Explanation :
# abc is a valid identifier
#
# Explanation :
# Student is  a valid identifier
#
# Explanation :
# result is a valid identifier
#
# **Q2 of 5**
#
# Identifiers cannot start with _____.
#
# - character []
# - digit [x]
# - _ []
# - $ []
#
# Explanation :
#
# Identifiers cannot start with a digit
#
#
# **Q3 of 5**
#
# What will be the output of the below code?
#
# ```java
# public static void main(String args[]) {
# 	int age;
# 	System.out.println(age);
# }
# ```
#
# - 0 []
# - garbage value []
# - compilation error : variable needs to be initialized before use [x]
# - 2147483647 []
#
# Explanation :
#
# A variable inside main method needs to be initialized before use, there will be a compilation error if it is not initialized
#
# **Q4 of 5**
#
# Which of the following are valid variable declarations?
#
# - float = 10.5f []
# - boolean isOn = “true” []
# - char gender = ‘F’ [x]
# - int value = 20 [x]
#
# Explanation :
# This is a valid declaration
#
# Explanation :
# This is a valid declaration
#
# **Q5 of 5**
#
# Which of these values can a boolean variable contain?
#
# - true [x]
# - false [x]
# - 0 []
# - 1 []
#
# Explanation :
# true is one of the values that a boolean variable can contain
#
# Explanation :
# false is one of the values that a boolean variable can contain
